# %% [markdown]
# # Data Wrangling: Medical Supplier Dataset (main)
#
# This notebook goes beyond basic cleaning and demonstrates professional-grade data wrangling techniques using the 63,000+ row medical supplier dataset. Each task includes output validation to show the impact of the transformation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load the Dataset

# %%
pd.set_option('display.max_columns', None)

df = pd.read_csv("../data/raw/Medical-Equipment-Suppliers.csv", low_memory=False)
print("Initial shape:", df.shape)
df.head()
# Out:
# Initial shape: (63112, 17)
#    provider_id  acceptsassignement participationbegindate  \
# 0     20561045                True             2007-11-01
# 1     20489003               False             2014-07-01
# 2     20447711               False             2019-01-01
# 3     20541431               False             2010-03-31
# 4     20469089                True             2016-12-15
#
#                businessname              practicename  \
# 0       HARTIG DRUG CO CORP       HARTIG DRUG STORE 5
# 1   WAL-MART STORES EAST LP  WALMART PHARMACY 10-0674
# 2       OHIO CVS STORES LLC       CVS PHARMACY #03306
# 3  LUXOTTICA OF AMERICA INC        LENSCRAFERS #00855
# 4   SPECIALTY INFUSIONS INC           PRIME INFUSIONS
#
#           practiceaddress1 practiceaddress2  practicecity practicestate  \
# 0       11002 BARTELL BLVD              NaN        GALENA            IL
# 1      1112 NASHVILLE PIKE              NaN      GALLATIN            TN
# 2  1949 WEST MARKET STREET              NaN         AKRON            OH
# 3          2526 S THIRD ST              NaN  JACKSONVILLE            FL
# 4            1624 BROADWAY              NaN      BROOKLYN            NY
#
#    practicezip9code  telephonenumber   specialitieslist providertypelist  \
# 0         610368215       8157772700           Pharmacy              NaN
# 1         370667116       6154521110  Optician|Pharmacy              NaN
# 2         443136910       3308675410           Pharmacy              NaN
# 3         322506024       9042472374           Optician              NaN
# 4         112071026       7184434000           Pharmacy              NaN
#
#                                         supplieslist  latitude  longitude  \
# 0  Enteral Nutrients|Walkers|Tracheotomy Supplies...  42.44484  -90.45593
# 1  Enteral Nutrients|Oral Antiemetic Drugs|Blood ...  36.37498  -86.47526
# 2  Blood Glucose Monitors/Supplies (Mail Order)|P...  41.11353  -81.57820
# 3         Prosthetic Lenses: Conventional Eyeglasses  30.26696  -81.38857
# 4  External Infusion Pumps and/or Supplies|Osteog...  40.68483  -73.91404
#
#    is_contracted_for_cba
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False

# %% [markdown]
# ## Drop Sparse Columns

# %%
threshold = len(df) * 0.8
sparse_cols = df.columns[df.isnull().sum() > threshold]
df.drop(columns=sparse_cols, inplace=True)
print("Dropped columns:", list(sparse_cols))
print("New shape:", df.shape)
# Out:
# Dropped columns: ['providertypelist']
# New shape: (63112, 16)

# %% [markdown]
# ## Convert Dates & Derive Account Age

# %%
df['participationbegindate'] = pd.to_datetime(df['participationbegindate'], errors='coerce')
df['account_age_years'] = 2025 - df['participationbegindate'].dt.year
print(df[['participationbegindate', 'account_age_years']].head())
# Out:
#   participationbegindate  account_age_years
# 0             2007-11-01                 18
# 1             2014-07-01                 11
# 2             2019-01-01                  6
# 3             2010-03-31                 15
# 4             2016-12-15                  9

# %% [markdown]
# ## Group States into Regions

# %%
west = ['CA', 'WA', 'OR', 'NV']
south = ['TX', 'FL', 'GA']
df['region'] = df['practicestate'].apply(
    lambda x: 'West' if x in west else ('South' if x in south else 'Other')
)
print(df['region'].value_counts())
# Out:
# region
# Other    44355
# South    11163
# West      7594
# Name: count, dtype: int64

# %% [markdown]
# ## Handle Specialities List (Split & Expand Preview)

# %%
df['specialitieslist'] = df['specialitieslist'].fillna('Unknown')
df['first_speciality'] = df['specialitieslist'].apply(lambda x: x.split('|')[0] if isinstance(x, str) else x)
print(df[['specialitieslist', 'first_speciality']].head())
# Out:
#     specialitieslist first_speciality
# 0           Pharmacy         Pharmacy
# 1  Optician|Pharmacy         Optician
# 2           Pharmacy         Pharmacy
# 3           Optician         Optician
# 4           Pharmacy         Pharmacy

# %% [markdown]
# ## Simulate Price Column and Detect Outliers

# %%
np.random.seed(42)
df['price'] = np.random.uniform(5, 500, len(df))
outliers = df[df['price'] > 450]
print("Outliers detected (price > 450):", outliers.shape[0])
# Out:
# Outliers detected (price > 450): 6328

# %% [markdown]
# ## Flag Incomplete or Low-Quality Records

# %%
df['data_quality_flag'] = df[['specialitieslist', 'supplieslist', 'latitude']].isnull().any(axis=1)
print("Rows flagged as incomplete:", df['data_quality_flag'].sum())
# Out:
# Rows flagged as incomplete: 49

# %% [markdown]
# ## Aggregate: Count Providers Per Region

# %%
region_counts = df.groupby('region')['provider_id'].count()
print(region_counts)
# Out:
# region
# Other    44355
# South    11163
# West      7594
# Name: provider_id, dtype: int64

# %%
df
# Out:
#        provider_id  acceptsassignement participationbegindate  \
# 0         20561045                True             2007-11-01
# 1         20489003               False             2014-07-01
# 2         20447711               False             2019-01-01
# 3         20541431               False             2010-03-31
# 4         20469089                True             2016-12-15
# ...            ...                 ...                    ...
# 63107     20678339                True             1984-10-01
# 63108     20592113               False             2004-01-01
# 63109     20316683                True             2023-01-01
# 63110     20474897                True             2016-12-07
# 63111     20374301                True             2022-03-01
#
#                    businessname              practicename  \
# 0           HARTIG DRUG CO CORP       HARTIG DRUG STORE 5
# 1       WAL-MART STORES EAST LP  WALMART PHARMACY 10-0674
# 2           OHIO CVS STORES LLC       CVS PHARMACY #03306
# 3      LUXOTTICA OF AMERICA INC        LENSCRAFERS #00855
# 4       SPECIALTY INFUSIONS INC           PRIME INFUSIONS
# ...                         ...                       ...
# 63107  VALLEY VISION CLINIC LTD      VALLEY VISION CLINIC
# 63108               LINCARE INC                   LINCARE
# 63109          CVS PHARMACY INC       CVS PHARMACY #07458
# 63110  PUBLIX SUPER MARKETS INC     PUBLIX PHARMACY #1775
# 63111               WALGREEN CO           WALGREENS #7789
#
#               practiceaddress1 practiceaddress2   practicecity practicestate  \
# 0           11002 BARTELL BLVD              NaN         GALENA            IL
# 1          1112 NASHVILLE PIKE              NaN       GALLATIN            TN
# 2      1949 WEST MARKET STREET              NaN          AKRON            OH
# 3              2526 S THIRD ST              NaN   JACKSONVILLE            FL
# 4                1624 BROADWAY              NaN       BROOKLYN            NY
# ...                        ...              ...            ...           ...
# 63107     2200 S WASHINGTON ST              NaN    GRAND FORKS            ND
# 63108  1442 W BUSINESS PARK DR              NaN           OREM            UT
# 63109      3601 N BELT LINE RD              NaN      SUNNYVALE            TX
# 63110          2830 HIGHWAY 52              NaN  MONCKS CORNER            SC
# 63111             3200 S 7 HWY              NaN   BLUE SPRINGS            MO
#
#        practicezip9code  telephonenumber              specialitieslist  \
# 0             610368215       8157772700                      Pharmacy
# 1             370667116       6154521110             Optician|Pharmacy
# 2             443136910       3308675410                      Pharmacy
# 3             322506024       9042472374                      Optician
# 4             112071026       7184434000                      Pharmacy
# ...                 ...              ...                           ...
# 63107         582016346       7017753135          Optometrist|Optician
# 63108         840582223       8012243338  Medical Supply Company Other
# 63109         751829235       9722796997                      Pharmacy
# 63110             29461       8438096083                      Pharmacy
# 63111         640145300       8162208455                      Pharmacy
#
#                                             supplieslist  latitude  longitude  \
# 0      Enteral Nutrients|Walkers|Tracheotomy Supplies...  42.44484  -90.45593
# 1      Enteral Nutrients|Oral Antiemetic Drugs|Blood ...  36.37498  -86.47526
# 2      Blood Glucose Monitors/Supplies (Mail Order)|P...  41.11353  -81.57820
# 3             Prosthetic Lenses: Conventional Eyeglasses  30.26696  -81.38857
# 4      External Infusion Pumps and/or Supplies|Osteog...  40.68483  -73.91404
# ...                                                  ...       ...        ...
# 63107  Prosthetic Lenses: Conventional Eyeglasses|Pro...  47.89822  -97.04570
# 63108  Blood Glucose Monitors/Supplies (Mail Order)|P...  40.27440 -111.72970
# 63109  Heat & Cold Applications|Walkers|Oral Anticanc...  32.81465  -96.59612
# 63110  Oral Anticancer Drugs|Epoetin|Oral Antiemetic ...  33.16419  -80.01934
# 63111  Oral Anticancer Drugs|Epoetin|Oral Antiemetic ...  38.98739  -94.27345
#
#        is_contracted_for_cba  account_age_years region  \
# 0                      False                 18  Other
# 1                      False                 11  Other
# 2                      False                  6  Other
# 3                      False                 15  South
# 4                      False                  9  Other
# ...                      ...                ...    ...
# 63107                  False                 41  Other
# 63108                  False                 21  Other
# 63109                  False                  2  South
# 63110                  False                  9  Other
# 63111                  False                  3  Other
#
#                    first_speciality       price  data_quality_flag
# 0                          Pharmacy  190.397359              False
# 1                          Optician  475.603582              False
# 2                          Pharmacy  367.337001              False
# 3                          Optician  301.335950              False
# 4                          Pharmacy   82.229227              False
# ...                             ...         ...                ...
# 63107                   Optometrist  412.018203              False
# 63108  Medical Supply Company Other  344.064415              False
# 63109                      Pharmacy  238.377114              False
# 63110                      Pharmacy  204.809964              False
# 63111                      Pharmacy  404.174024              False
#
# [63112 rows x 21 columns]

# %% [markdown]
# ## Save wrangled data for further analysis

# %%
df.to_csv('../data/processed/medical_suppliers_wrangled.csv', index=False)

# %% [markdown]
# ## Summary of these tasks
# - Sparse columns dropped: High missingness
# - Dates parsed, account age derived
# - Categorical grouping by region
# - Lists split and simplified
# - Outliers simulated and flagged
# - Missing fields flagged for review
# - Ready for downstream analysis or Excel export
